# %% [markdown]
# #### Import Dati

# %%
import pandas as pd
import numpy as np
import re
import math
import os
import joblib

# %%
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
import sklearn.model_selection  as skl_msel
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sklearn.metrics  as skl_metr

# %%
data_dir = os.path.join("..", "data")
df = pd.read_parquet(os.path.join(data_dir,'df_def.parquet'))

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 76 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   giorno                             2087 non-null   datetime64[ms]
#  1   PM10                               2087 non-null   float64
#  2   media_NO2                          2087 non-null   float64
#  3   mediana_NO2                        2087 non-null   float64
#  4   massimo_NO2                        2087 non-null   float64
#  5   flag_PM25_missing                  1396 non-null   object
#  6   flag_PM25_SF                       691 non-null    object
#  7   flag_O3_missing                    1382 non-null   object
#  8   flag_O3_VC                         691 non-null    object
#  9   flag_O3_interpol                   691 non-null    object
#  10  mese_giorno                        2087 non-null   str
#  11  anno                               2087 non-null   int32
#  12  flag_NO2_2023                      2087 non-null   bool
#  13  flag_PM25_GM                       705 non-null    object
#  14  flag_PM25_interpol                 705 non-null    object
#  15  flag_NO2_missing                   705 non-null    object
#  16  flag_NO2_GM                        705 non-null    object
#  17  flag_C6H6_interpol                 705 non-null    object
#  18  flag_NOX_interpol                  705 non-null    object
#  19  flag_NOX_2019                      705 non-null    object
#  20  flag_CO_2023                       705 non-null    object
#  21  flag_NO_2023                       705 non-null    object
#  22  flag_O3_GM                         691 non-null    object
#  23  flag_missing                       2087 non-null   bool
#  24  temperature_2m_mean                2087 non-null   float32
#  25  temperature_2m_max                 2087 non-null   float32
#  26  temperature_2m_min                 2087 non-null   float32
#  27  apparent_temperature_mean          2087 non-null   float32
#  28  apparent_temperature_max           2087 non-null   float32
#  29  apparent_temperature_min           2087 non-null   float32
#  30  wind_speed_10m_max                 2087 non-null   float32
#  31  wind_gusts_10m_max                 2087 non-null   float32
#  32  wind_direction_10m_dominant        2087 non-null   float32
#  33  shortwave_radiation_sum            2087 non-null   float32
#  34  et0_fao_evapotranspiration         2087 non-null   float32
#  35  daylight_duration                  2087 non-null   float32
#  36  sunshine_duration                  2087 non-null   float32
#  37  precipitation_sum                  2087 non-null   float32
#  38  snowfall_sum                       2087 non-null   float32
#  39  precipitation_hours                2087 non-null   float32
#  40  cloud_cover_mean                   2087 non-null   float32
#  41  cloud_cover_max                    2087 non-null   float32
#  42  cloud_cover_min                    2087 non-null   float32
#  43  dew_point_2m_mean                  2087 non-null   float32
#  44  dew_point_2m_max                   2087 non-null   float32
#  45  dew_point_2m_min                   2087 non-null   float32
#  46  wet_bulb_temperature_2m_mean       2087 non-null   float32
#  47  wet_bulb_temperature_2m_max        2087 non-null   float32
#  48  wet_bulb_temperature_2m_min        2087 non-null   float32
#  49  vapour_pressure_deficit_max        2087 non-null   float32
#  50  soil_moisture_0_to_7cm_mean        2087 non-null   float32
#  51  soil_moisture_0_to_100cm_mean      2087 non-null   float32
#  52  soil_moisture_28_to_100cm_mean     2087 non-null   float32
#  53  soil_moisture_7_to_28cm_mean       2087 non-null   float32
#  54  soil_temperature_0_to_100cm_mean   2087 non-null   float32
#  55  soil_temperature_0_to_7cm_mean     2087 non-null   float32
#  56  soil_temperature_28_to_100cm_mean  2087 non-null   float32
#  57  soil_temperature_7_to_28cm_mean    2087 non-null   float32
#  58  relative_humidity_2m_mean          2087 non-null   float32
#  59  relative_humidity_2m_max           2087 non-null   float32
#  60  snowfall_water_equivalent_sum      2087 non-null   float32
#  61  pressure_msl_mean                  2087 non-null   float32
#  62  relative_humidity_2m_min           2087 non-null   float32
#  63  pressure_msl_max                   2087 non-null   float32
#  64  pressure_msl_min                   2087 non-null   float32
#  65  surface_pressure_mean              2087 non-null   float32
#  66  surface_pressure_max               2087 non-null   float32
#  67  surface_pressure_min               2087 non-null   float32
#  68  wind_gusts_10m_mean                2087 non-null   float32
#  69  wind_speed_10m_mean                2087 non-null   float32
#  70  wind_gusts_10m_min                 2087 non-null   float32
#  71  wind_speed_10m_min                 2087 non-null   float32
#  72  sunrise_minutes                    2087 non-null   int32
#  73  sunset_minutes                     2087 non-null   int32
#  74  weather_description                2087 non-null   str
#  75  target_pm10                        2087 non-null   int64
# dtypes: bool(2), datetime64[ms](1), float32(48), float64(4), int32(3), int64(1), object(15), str(2)
# memory usage: 839.3+ KB

# %%
list_var = ['precipitation_sum',
                    'cloud_cover_max',
                    'wind_speed_10m_min',
                    'wind_gusts_10m_max',
                    'pressure_msl_max',
                    'soil_moisture_28_to_100cm_mean',
                    'dew_point_2m_max',
                    'temperature_2m_max',
                    'shortwave_radiation_sum'
                     ]

# %%
# split direttamente sul dataframe
xtr, xte, ytr, yte = skl_msel.train_test_split(
    df,
    df['target_pm10'],
    test_size=0.30,
    random_state=33
)

# flag basati sull'index
df['flag train'] = df.index.isin(xtr.index)
df['flag test'] = df.index.isin(xte.index)

# %% [markdown]
# #### Modello

# %%
params = {'learning_rate': 0.03, 'max_depth': 4, 'n_estimators': 700}

# %%
from xgboost import XGBClassifier

# calcolo peso per class imbalance
n_neg = (df['target_pm10'] == 0).sum()
n_pos = (df['target_pm10'] == 1).sum()
scale_pos_weight = n_neg / n_pos

cla_xgb = XGBClassifier(
    **params,
    scale_pos_weight=scale_pos_weight
)

cla_xgb.fit(
    df.loc[df['flag train'], list_var].values,
    df.loc[df['flag train'], 'target_pm10'].values
)

# probabilità della classe 1
df['proba (xgb)'] = cla_xgb.predict_proba(
    df.loc[:, list_var].values
)[:, 1]

df['prediction (xgb)'] = (df['proba (xgb)'] > 0.3).astype(int)

# %% [markdown]
# #### Precision

# %%
pre_xgb = skl_metr.precision_score(df.loc[df['flag test'], 'target_pm10'] == 1,
                                    df.loc[df['flag test'], 'prediction (xgb)'] == 1)

print(f'Model precision (decision xgb): {pre_xgb:.2}')
# Out:
# Model precision (decision xgb): 0.71

# %% [markdown]
# #### Recall

# %%
rec_xgb = skl_metr.recall_score(df.loc[df['flag test'], 'target_pm10'] == 1,
                                 df.loc[df['flag test'], 'prediction (xgb)'] == 1)

print(f'Model recall (xgb): {rec_xgb:.2}')
# Out:
# Model recall (xgb): 0.91

# %% [markdown]
# #### Table

# %%
df_pivot = pd.pivot_table(df.loc[df['flag test'], :],
                          index='target_pm10', columns='prediction (xgb)',
                          values='giorno', aggfunc='count', fill_value=0)
df_pivot.style.background_gradient(vmin=0, vmax=5).format(precision=0)
# Out:
# <style type="text/css">
# #T_3aba0_row0_col0, #T_3aba0_row0_col1, #T_3aba0_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3aba0_row1_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3aba0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >prediction (xgb)</th>
#       <th id="T_3aba0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3aba0_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_pm10</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3aba0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3aba0_row0_col0" class="data row0 col0" >583</td>
#       <td id="T_3aba0_row0_col1" class="data row0 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3aba0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3aba0_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_3aba0_row1_col1" class="data row1 col1" >29</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sklearn.metrics as skl_metr

df_test = df.loc[df['flag test']]

y_true = df_test['target_pm10']

models = {
    "xgb": "prediction (xgb)"
}

results = []

for name, col in models.items():
    y_pred = df_test[col]

    results.append({
        "Model": name,
        "Accuracy": skl_metr.accuracy_score(y_true, y_pred),
        "Precision": skl_metr.precision_score(y_true, y_pred),
        "Recall": skl_metr.recall_score(y_true, y_pred),
        "F1-score": skl_metr.f1_score(y_true, y_pred),
        "MCC": skl_metr.matthews_corrcoef(y_true, y_pred)
    })

df_results = pd.DataFrame(results)

df_results = df_results.round(4)
df_results
# Out:
#   Model  Accuracy  Precision  Recall  F1-score     MCC
# 0   xgb    0.9761     0.7073  0.9062    0.7945  0.7888

# %% [markdown]
# Abbiamo scelto un modello con alta recall perchè
# https://www.airc.it/cancro/prevenzione-tumore/prevenzione-per-tutti/inquinamento-atmosferico-prevenzione-dei-rischi-per-la-salute

# %% [markdown]
# ## Feature importance

# %%
modello = cla_xgb.fit(
    df.loc[df['flag train'], list_var].values,
    df.loc[df['flag train'], 'target_pm10'].values
)

import shap

# feature matrix e target
X = df[list_var]
y = df["target_pm10"]

# background (campione del dataset)
background = X.sample(100, random_state=42)

# SHAP explainer
explainer = shap.Explainer(modello, background)

# calcolo valori SHAP
shap_values = explainer(X)

# plot importanza globale
shap.plots.bar(shap_values)
# Out:
#  96%|=================== | 1994/2087 [00:17<00:00]

# %% [markdown]
# Mostra l’importanza basata sul massimo effetto assoluto: prende il caso più estremo
#
# Dice quali variabili possono avere effetti fortissimi anche se rari

# %%
shap.plots.bar(shap_values.abs.max(0))

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# ## Salvo il modello

# %%
model_path = os.path.join("..", "data", "xgb_model.pkl")

joblib.dump(cla_xgb, model_path)
# Out:
# ['..\\data\\xgb_model.pkl']
